# %%
from bs4 import BeautifulSoup
import re
import requests
import pandas as pd
import os

# %%
def re_url(url):
    try:
        response = requests.get(url)
        if response.status_code == 200:
            return response.text
        else:
            print(f"Failed to retrieve data from {url}. Status code: {response.status_code}")
            return None
    except Exception as e:
        print(f"Error while processing {url}: {str(e)}")
        return None

# %%
def scrape_html(html):
    soup = BeautifulSoup(html, 'html.parser')
    return soup

# %%
def get_url(soup):
    url_list = []
    anchors = soup.find_all('a', class_='showdown-dn-link')
    urls = [anchor['href'] for anchor in anchors]
    for url in urls:
        url_list.append("https://rip.ie" + url)
    return url_list

# %%
def get_ID(url):
    url_pattern = r'https://rip.ie/death-notice/([^/]+)-([^/]+)-([^/]+)(?:-([^/]+))?-(\d+)'
    m = re.match(url_pattern, url)
    if m:
        return m.group(5)  
    else:
        print("Pattern did not match.")

# %%
def get_name(soup):
    name_val = soup.find('h1', class_='DeathNotice_person-name__lkvex')
    if name_val:
        name = name_val.get_text()
        name = name.strip()
        name = name.replace("Â", "")
        name = name.replace("nee", "née")
        name = name.replace("nÃ©e", "née")
        name = name.replace("\n", " ")
        name = name.replace("â", "’")
        return name
    else:
        return None

# %%
def get_loc(soup):
    locations = {}
    loc_val = soup.find('div', class_='DeathNotice_tags-item__Fp1X4')
    if loc_val:
        raw_loc = loc_val.get_text()
        loc = [word.strip() for word in raw_loc.split(",") + raw_loc.split("/")]
        city_town = loc[-1]
        locations["City"] = city_town.split(",")[-1]
        locations["Town"] = city_town.split(",")[:-1]
        return locations
    else:
        return None

# %%
def get_dates(soup):
    date_list = {}

    published_date_value = soup.find('p', class_='DeathNotice_dates-published-date__M0A_i')
    if published_date_value:
        date_list["Published Date"] = published_date_value.get_text()
    else:
        date_list["Published Date"] = None

    death_date_value = soup.find('p', class_='DeathNotice_dates-death-date__bR7g_')
    if death_date_value:
        date_list["Death Date"] = death_date_value.get_text()
    else:
        date_list["Death Date"] = None

    return date_list

# %%
def get_obituary(soup):
    description = soup.find('div', class_='DeathNotice_description__sY_tC word-break')
    if description:
        text = description.get_text()
        text = text.strip()
        text = text.replace("Â", "")
        text = text.replace("nee", "née")
        text = text.replace("nÃ©e", "née")
        text = text.replace("\n", " ")
        text = text.replace("â", "’")
        text = text.replace("Å", "")
        text = text.replace("Ä", "")
        text = text.replace("", "")
        return text
    else:
        return None

# %%
def get_page_data(url_list):
    data_list = []
        
    for u in url_list:
        s = scrape_html(re_url(u))
        identity = get_ID(u)
        name = get_name(s)
        loc = get_loc(s)
        dates = get_dates(s)
        obituary_text = get_obituary(s)

        data_list.append({
            "Name": name,
            "ID": identity,
            "City": loc["City"],
            "Town": loc["Town"],
            "Published Date": dates["Published Date"],
            "Death Date": dates["Death Date"],
            "Obituary Text": obituary_text
        })

    df = pd.DataFrame(data_list)
    return df

# %%
def get_entry_urls(page_number):
    entry_urls = []
    for p in range(1, page_number+1):
        base_url = "https://rip.ie/death-notice/s/all?page=" + str(p) + "&start=today+00%3A00%3A00&end=today&sortField=a.createdAtCastToDate&sortDir=ASC&view=list"
        entry_urls.append(base_url)
    return entry_urls

# %%
get_entry_urls(2)
# Out:
# ['https://rip.ie/death-notice/s/all?page=1&start=today+00%3A00%3A00&end=today&sortField=a.createdAtCastToDate&sortDir=ASC&view=list',
#  'https://rip.ie/death-notice/s/all?page=2&start=today+00%3A00%3A00&end=today&sortField=a.createdAtCastToDate&sortDir=ASC&view=list']

# %%
def get_url_list(entry_urls):
    for entry_url in entry_urls:
        page_data = re_url(entry_url)
        if page_data:
            url_list = get_url(scrape_html(page_data))
    return url_list

# %%
get_url_list(get_entry_urls(2))
# Out:
# ['https://rip.ie/death-notice/denis-frawley-dublin-clonsilla-533645',
#  'https://rip.ie/death-notice/ita-feely-dublin-terenure-533644',
#  'https://rip.ie/death-notice/ita-feely-laois-abbeyleix-533644',
#  'https://rip.ie/death-notice/anthony-tony-mcnamara-tipperary-carrick-on-suir-533643',
#  'https://rip.ie/death-notice/myles-byrne-offaly-edenderry-533642',
#  'https://rip.ie/death-notice/peter-pierre-kiernan-dublin-ringsend-533641',
#  'https://rip.ie/death-notice/denis-bucke-limerick-feohanagh-533640',
#  'https://rip.ie/death-notice/denis-bucke-limerick-ballagh-533640',
#  'https://rip.ie/death-notice/john-cliffe-waterford-abbeyside-533639',
#  'https://rip.ie/death-notice/michael-mike-carty-dublin-carpenterstown-533638',
#  'https://rip.ie/death-notice/michael-mike-carty-galway-newbridge-533638',
#  'https://rip.ie/death-notice/john-mccormack-westmeath-delvin-533637',
#  'https://rip.ie/death-notice/catherine-kitty-daly-cork-charleville-533636',
#  'https://rip.ie/death-notice/anthony-tony-odonovan-sligo-strandhill-533635',
#  'https://rip.ie/death-notice/keith-chipperfield-dublin-rathfarnham-533634',
#  'https://rip.ie/death-notice/mark-ryan-dublin-blackrock-533633',
#  'https://rip.ie/death-notice/patrick-paddy-maguire-louth-dromiskin-533632',
#  'https://rip.ie/death-notice/jean-jane-daisy-malone-dublin-clondalkin-533631',
#  'https://rip.ie/death-notice/thomas-warde-galway-tuam-533630',
#  'https://rip.ie/death-notice/liam-murray-galway-loughrea-533629',
#  'https://rip.ie/death-notice/charlotte-barrett-cork-togher-533628',
#  'https://rip.ie/death-notice/nellie-connolly-galway-oranmore-533627',
#  'https://rip.ie/death-notice/denis-decie-hassett-tipperary-nenagh-533626',
#  'https://rip.ie/death-notice/george-lee-mayo-kiltimagh-533625',
#  'https://rip.ie/death-notice/george-lee-kilkenny-stoneyford-533625',
#  'https://rip.ie/death-notice/margaret-reilly-longford-granard-533623',
#  'https://rip.ie/death-notice/tony-mcguinness-meath-duleek-533622',
#  'https://rip.ie/death-notice/tony-mcguinness-meath-bellewstown-533622',
#  'https://rip.ie/death-notice/tommy-mccarthy-galway-tuam-533621',
#  'https://rip.ie/death-notice/patrick-paddy-moore-limerick-doon-533620',
#  'https://rip.ie/death-notice/patrick-paddy-moore-tipperary-533620',
#  'https://rip.ie/death-notice/seamus-barry-cork-bishopstown-533619',
#  'https://rip.ie/death-notice/seamus-barry-cork-courtmacsherry-533619',
#  'https://rip.ie/death-notice/piotr-rys-waterford-ballymacarbry-533618',
#  'https://rip.ie/death-notice/john-james-hoban-mayo-ballina-533617',
#  'https://rip.ie/death-notice/anna-may-mcloughlin-longford-edgeworthstown-533616',
#  'https://rip.ie/death-notice/samantha-heraty-westmeath-mullingar-533615',
#  'https://rip.ie/death-notice/bridget-oconnell-limerick-caherconlish-533614',
#  'https://rip.ie/death-notice/cornelius-con-ogorman-kerry-beaufort-533613',
#  'https://rip.ie/death-notice/cornelius-con-ogorman-kerry-lisselton-533613']

# %%
rip_df = get_page_data(get_url_list(get_entry_urls(2)))
rip_df
# Out:
#                                         Name      ID        City  \
# 0                              Denis Frawley  533645      Dublin
# 1                      Ita Feely(née Deegan)  533644       Laois
# 2                      Ita Feely(née Deegan)  533644       Laois
# 3                    Anthony (Tony) McNamara  533643   Tipperary
# 4                                Myles BYRNE  533642      Offaly
# 5                     Peter (Pierre) KIERNAN  533641      Dublin
# 6                                Denis Bucke  533640    Limerick
# 7                                Denis Bucke  533640    Limerick
# 8                                John Cliffe  533639   Waterford
# 9                       Michael (Mike) CARTY  533638      Galway
# 10                      Michael (Mike) CARTY  533638      Galway
# 11                            John McCormack  533637   Westmeath
# 12         Catherine (Kitty) Daly(née Hayes)  533636        Cork
# 13                  Anthony (Tony) O'Donovan  533635       Sligo
# 14                        Keith Chipperfield  533634      Dublin
# 15                                 Mark Ryan  533633      Dublin
# 16                   Patrick (Paddy) Maguire  533632       Louth
# 17  Jean (Jane) (Daisy) Malone(née Tompkins)  533631      Dublin
# 18                              Thomas Warde  533630      Galway
# 19                               Liam Murray  533629      Galway
# 20           CHARLOTTE BARRETT(née PHILPOTT)  533628        Cork
# 21                Nellie Connolly(née Coyne)  533627      Galway
# 22                     DENIS (DECIE) HASSETT  533626   Tipperary
# 23                                George Lee  533625    Kilkenny
# 24                                George Lee  533625    Kilkenny
# 25                           Margaret Reilly  533623    N39 A3T8
# 26                           Tony McGuinness  533622       Meath
# 27                           Tony McGuinness  533622       Meath
# 28                            Tommy McCarthy  533621      Galway
# 29                     Patrick (Paddy) Moore  533620   Tipperary
# 30                     Patrick (Paddy) Moore  533620   Tipperary
# 31                              Seamus Barry  533619        Cork
# 32                              Seamus Barry  533619        Cork
# 33                                 Piotr Rys  533618   Waterford
# 34                          John James Hoban  533617        Mayo
# 35            Anna May McLoughlin(née Kelly)  533616    Longford
# 36                           Samantha Heraty  533615   Westmeath
# 37            Bridget O'Connell(née Murnane)  533614    Limerick
# 38                  Cornelius (Con) O'Gorman  533613       Kerry
# 39                  Cornelius (Con) O'Gorman  533613       Kerry
#
#                                                  Town  \
# 0                                         [Clonsilla]
# 1                                         [Abbeyleix]
# 2                                         [Abbeyleix]
# 3                    [Collins Park,  Carrick-on-Suir]
# 4                         [Gilroy Avenue,  Edenderry]
# 5                                          [Ringsend]
