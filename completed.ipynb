# %%
from bs4 import BeautifulSoup
import re
import requests
import pandas as pd
import os

# %%
entry_urls = []

start_date = "2006-07-02"
end_date = "2006-07-05"
base_url = "https://rip.ie/death-notice/s/all?page={}&start={}%2B00%3A00%3A00&end={}&sortField=a.createdAtCastToDate&sortDir=DESC&view=boxes"
page_count = 2 #manually changed every time
#rough_count_deaths = page_count*40
#print(str(rough_count_deaths) + " deaths between " + start_date + " and " + end_date)

for i in range(1, page_count+1):
    entry_urls.append(base_url.format(i, start_date, end_date))

# %%
def re_url(url):
    try:
        response = requests.get(url)
        if response.status_code == 200:
            return response.text
        else:
            print(f"Failed to retrieve data from {url}. Status code: {response.status_code}")
            return None
    except Exception as e:
        print(f"Error while processing {url}: {str(e)}")
        return None

# %%
def scrape_html(html):
    soup = BeautifulSoup(html, 'html.parser')
    return soup

# %%
def get_url(soup):
    url_list = []
    anchors = soup.find_all('a', class_='showdown-dn-link')
    urls = [anchor['href'] for anchor in anchors]
    for url in urls:
        url_list.append("https://rip.ie" + url)
    return url_list

# %%
def get_individual_date(soup):
    date_list = {}

    published_date_value = soup.find('p', class_='DeathNotice_dates-published-date__M0A_i')
    if published_date_value:
        date_list["Published Date"] = published_date_value.get_text()
    else:
        date_list["Published Date"] = None

    death_date_value = soup.find('p', class_='DeathNotice_dates-death-date__bR7g_')
    if death_date_value:
        date_list["Death Date"] = death_date_value.get_text()
    else:
        date_list["Death Date"] = None

    return date_list

# %%
def get_obituary(soup):
    description = soup.find('div', class_='DeathNotice_description__sY_tC word-break')
    if description:
        text = description.get_text()
        text = text.strip()
        text = text.replace("Â", "")
        text = text.replace("nee", "née")
        text = text.replace("nÃ©e", "née")
        text = text.replace("\n", " ")
        text = text.replace("â", "’")
        return text
    else:
        return None

# %%
def get_page_data(entry_urls):
    data_list = []

    url_pattern = r'https://rip.ie/death-notice/([^/]+)-([^/]+)-([^/]+)(?:-([^/]+))?-(\d+)'

    for entry_url in entry_urls:
        page_data = re_url(entry_url)
        if page_data:
            url_list = get_url(scrape_html(page_data))
            
            for u in url_list:
                m = re.match(url_pattern, u)

                dates = get_individual_date(scrape_html(re_url(u)))
                obituary_text = get_obituary(scrape_html(re_url(u)))
                
                if m:
                    name = m.group(1)
                    city = m.group(2)
                    location = m.group(3)
                    identity = m.group(5)

                    data_list.append({
                                    "Name": name,
                                    "ID": identity,
                                    "City": city.capitalize(),
                                    "Location": location.capitalize(),
                                    "Published Date": dates["Published Date"],
                                    "Death Date": dates["Death Date"],
                                    "Obituary Text": obituary_text
                                })

                else:
                    print("Pattern did not match.")

    df = pd.DataFrame(data_list)
    return df

# %%
rip_df = get_page_data(entry_urls)
rip_df
# Out:
#                   Name      ID       City     Location  \
# 0        mary-mcfadden  533157      Louth      Dundalk
# 1        frank-minogue  533156  Westmeath      Athlone
# 2                billy  533155      Horan      Kildare
# 3        john-corcoran  533154       Cork        Conna
# 4        john-corcoran  533154       Cork  Castlelyons
# ..                 ...     ...        ...          ...
# 75         audrey-cole  533128     Dublin  Rathfarnham
# 76  lucy-mary-monaghan  533127     Offaly      Ferbane
# 77     james-jim-doyle  533126     Carlow  Hacketstown
# 78     james-jim-doyle  533126     Carlow  Ballymurphy
# 79       edward-lunney  533125     Dublin      Coolock
#
#                  Published Date                     Death Date  \
# 0   Wednesday 18th October 2023      Tuesday 17th October 2023
# 1   Wednesday 18th October 2023     Saturday 14th October 2023
# 2   Wednesday 18th October 2023    Wednesday 18th October 2023
# 3   Wednesday 18th October 2023    Wednesday 18th October 2023
# 4   Wednesday 18th October 2023    Wednesday 18th October 2023
# ..                          ...                            ...
# 75  Wednesday 18th October 2023      Tuesday 17th October 2023
# 76  Wednesday 18th October 2023  Wednesday 13th September 2023
# 77  Wednesday 18th October 2023    Wednesday 18th October 2023
# 78  Wednesday 18th October 2023    Wednesday 18th October 2023
# 79  Wednesday 18th October 2023      Tuesday 17th October 2023
#
#                                         Obituary Text
# 0   On October 17th, 2023, peacefully, in the dedi...
# 1   Frank passed away peacefully on Saturday the 1...
# 2   Billy Horan, Brannockstown, Kilcullen, Co. Kil...
# 3   John Corcoran Monty’s Meadow, Conna and former...
# 4   John Corcoran Monty’s Meadow, Conna and former...
# ..                                                ...
# 75  COLE, Audrey Phyllis (née Stevens). Late of Ra...
# 76  Lucy Monaghan, (née Dolan), London, England, L...
# 77  James (Jim) Doyle, Woodside House, Hacketstown...
# 78  James (Jim) Doyle, Woodside House, Hacketstown...
# 79  Lunney, Edward â 17th October 2023, (Coolock...
#
# [80 rows x 7 columns]

# %%
output_directory = '/Users/idilbilgic/Desktop/STAGE4.1/COMP30170/suicide_rates_IE/output_monthly'
rip_df.to_csv(os.path.join(output_directory, 'rip_output_2006_07.csv'), index=False)

# %%
#rip_df.to_csv('rip_output_2006.csv', index=False)
